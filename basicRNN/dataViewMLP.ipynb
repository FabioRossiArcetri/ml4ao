# %%
import pandas as pd
import os
import torch

# %%
from basicRNN import *
print(device)
# Out:
# cuda

# %%
ts = trainingService('paramsConfigMLP3.yml')
ts.loadData(True)
# Out:
# self.spacing 1
# data.shape torch.Size([9181, 200])
# labels.shape torch.Size([9181, 3])
# labels scales tensor([2.0173, 3.5971, 1.6332])
# labels scales tensor([0.5048, 0.5396, 0.4905])
# train_dataset 7345
# test_dataset 1836

# %%
ts.setupModel()

# %%
ts.loadModel()

# %%
ts.trainModel(learning_rate=1e-3, num_epochs=50)
ts.trainModel(learning_rate=1e-4, num_epochs=50)
ts.trainModel(learning_rate=1e-5, num_epochs=50)
# Out:
# Epoch [5/50]], Loss: 0.002359, , Loss Val: 0.003571
# Epoch [10/50]], Loss: 0.002826, , Loss Val: 0.003086
# Epoch [15/50]], Loss: 0.002410, , Loss Val: 0.002099
# Epoch [20/50]], Loss: 0.002419, , Loss Val: 0.003640
# Epoch [25/50]], Loss: 0.002177, , Loss Val: 0.002676
# Epoch [30/50]], Loss: 0.002463, , Loss Val: 0.002777
# Epoch [35/50]], Loss: 0.003081, , Loss Val: 0.003172
# Epoch [40/50]], Loss: 0.002460, , Loss Val: 0.002253
# Epoch [45/50]], Loss: 0.003944, , Loss Val: 0.002333
# Epoch [50/50]], Loss: 0.003287, , Loss Val: 0.002534
# Epoch [5/50]], Loss: 0.002874, , Loss Val: 0.002464
# Epoch [10/50]], Loss: 0.002345, , Loss Val: 0.002714
# Epoch [15/50]], Loss: 0.002637, , Loss Val: 0.002318
# Epoch [20/50]], Loss: 0.003230, , Loss Val: 0.003094
# Epoch [25/50]], Loss: 0.001859, , Loss Val: 0.002500
# Epoch [30/50]], Loss: 0.002243, , Loss Val: 0.003372
# Epoch [35/50]], Loss: 0.003012, , Loss Val: 0.003201
# Epoch [40/50]], Loss: 0.002408, , Loss Val: 0.002609
# ...

# %%
ts.saveModel()

# %%
plotResults(ts, [0,1,2])
# Out:
# Results for:  Seeing
# Mean/Median Absolute error TEST: 0.03030471 0.02404292
# Mean/Median Absolute error TRAIN: 0.03035187946117826 0.023919209837913513
# R^2 0.9195804910812831
# Mean/Median Relative error TEST: 0.061240994268466846 0.05083277182053808
# Mean/Median Relative error TRAIN: 0.06042185092315817 0.05030061983361078
# Results for:  Tau0
# Mean/Median Absolute error TEST: 0.06323618 0.04836124
# Mean/Median Absolute error TRAIN: 0.06057603762223663 0.047532111406326294
# R^2 0.7977070435233755
# Mean/Median Relative error TEST: 0.11507356984114529 0.09822919857153209
# Mean/Median Relative error TRAIN: 0.1133588655715459 0.09373674618425748
# Results for:  Strehl
# Mean/Median Absolute error TEST: 0.013678015 0.010051578
# Mean/Median Absolute error TRAIN: 0.014039204917488652 0.009907662868499756
# R^2 0.8851257967663878
# Mean/Median Relative error TEST: 0.03040008188230957 0.02001852064531217
# Mean/Median Relative error TRAIN: 0.03165124918210326 0.01989730359226422
